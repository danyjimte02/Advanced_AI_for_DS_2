# %% [markdown]
# ### Daniela Jiménez Téllez - A01654798

# %% [markdown]
# ---
#
# # Climate Data Time-Series
#
# ---
#
# You are again moving to another role, not at *The Weather Channel*, where you are ask to create a Weather Forecasting Model.
#
# For that, you will be using *Jena Climate* dataset recorded by the *Max Planck Institute for Biogeochemistry*.
#
# The dataset consists of 14 features such as temperature, pressure, humidity etc, recorded **once per 10 minutes**.
#
# Location: Weather Station, Max Planck Institute for Biogeochemistry in Jena, Germany
#
# Time-frame Considered: **Jan 10, 2009 - December 31, 2012**

# %% [markdown]
# Library Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import keras
from tensorflow.keras import layers, optimizers, regularizers

# %% [markdown]
# ### 1) Load your data
# Your data can be found on the Deep Learning Module under a file named: climate_data_2009_2012.csv

# %%
df = pd.read_csv("climate_data_2009_2012.csv")

# %% [markdown]
# ### 2) Data engineering
#
# You are given 3 lists:
# - titles: Display names of your columns
# - feature_keys: Names of the columns used as features
# - colors: The color to use when ploting that column's value

# %%
titles = [
    "Pressure",
    "Temperature",
    "Temperature in Kelvin",
    "Temperature (dew point)",
    "Relative Humidity",
    "Saturation vapor pressure",
    "Vapor pressure",
    "Vapor pressure deficit",
    "Specific humidity",
    "Water vapor concentration",
    "Airtight",
    "Wind speed",
    "Maximum wind speed",
    "Wind direction in degrees",
]

feature_keys = [
    "p (mbar)",
    "T (degC)",
    "Tpot (K)",
    "Tdew (degC)",
    "rh (%)",
    "VPmax (mbar)",
    "VPact (mbar)",
    "VPdef (mbar)",
    "sh (g/kg)",
    "H2OC (mmol/mol)",
    "rho (g/m**3)",
    "wv (m/s)",
    "max. wv (m/s)",
    "wd (deg)",
]

colors = [
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
    "gray",
    "olive",
    "cyan",
]

# %% [markdown]
# Let's look at the climate data:

# %%
df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1307.75      1.03           1.75     152.3
# 1       1309.80      0.72           1.50     136.1
# 2       1310.24      0.19           0.63     171.6
# 3       1309.19      0.34           0.50     198.0
# 4       1309.00      0.32           0.63     214.3

# %% [markdown]
# Define a function to show a plot of each column (using the respective color)

# %%
def show_raw_visualization(data, date_time_key):
    time_data = data[date_time_key]
    fig, axes = plt.subplots(
        nrows=7, ncols=2, figsize=(15, 20), dpi=80, facecolor="w", edgecolor="k"
    )
    for i in range(len(feature_keys)):
        key = feature_keys[i]
        c = colors[i % (len(colors))]
        t_data = data[key]
        t_data.index = time_data
        t_data.head()
        ax = t_data.plot(
            ax=axes[i // 2, i % 2],
            color=c,
            title="{} - {}".format(titles[i], key),
            rot=25,
        )
        ax.legend([titles[i]])
    plt.tight_layout()

# %% [markdown]
# Display each column in a plot using above funciton:

# %%
show_raw_visualization(df, "Date Time")

# %% [markdown]
# As you can see we have lots of data, this can be a challenge when we train our model, to resolve that we will reduce the resolution of our data, instead of having a climate signal each 10 minutes, we will have it each hour
#
# - Add a new column to your dataframe with the Date Time information
# - Name that column FormatedDateTime
# - Convert that column into date time data type
# - Set that column as the dataframe index
# - Regroup data to be each 1 hour instead of each 10 minutes
# - Save the grouped data into a dataframe called df_resampled
# - Remove the FormatedDateTime as the index.
# - Show the top 5 rows of df_resampled

# %%
df['FormatedDateTime'] = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df = df.set_index('FormatedDateTime')
df_resampled = df[feature_keys].resample('H').mean()
df_resampled = df_resampled.reset_index()

df_resampled.head()
# Out:
#      FormatedDateTime    p (mbar)  T (degC)    Tpot (K)  Tdew (degC)  \
# 0 2009-01-01 00:00:00  996.528000 -8.304000  265.118000    -9.120000
# 1 2009-01-01 01:00:00  996.525000 -8.065000  265.361667    -8.861667
# 2 2009-01-01 02:00:00  996.745000 -8.763333  264.645000    -9.610000
# 3 2009-01-01 03:00:00  996.986667 -8.896667  264.491667    -9.786667
# 4 2009-01-01 04:00:00  997.158333 -9.348333  264.026667   -10.345000
#
#       rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0  93.780000      3.260000      3.058000      0.202000   1.910000
# 1  93.933333      3.323333      3.121667      0.201667   1.951667
# 2  93.533333      3.145000      2.940000      0.201667   1.836667
# 3  93.200000      3.111667      2.898333      0.210000   1.811667
# 4  92.383333      3.001667      2.775000      0.231667   1.733333
#
#    H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)    wd (deg)
# 0         3.068000   1309.196000  0.520000       1.002000  174.460000
# 1         3.133333   1307.981667  0.316667       0.711667  172.416667
# 2         2.950000   1311.816667  0.248333       0.606667  196.816667
# 3         2.906667   1312.813333  0.176667       0.606667  157.083333
# 4         2.780000   1315.355000  0.290000       0.670000  150.093333

# %% [markdown]
# Let's look at our fields again

# %%
show_raw_visualization(df_resampled, "FormatedDateTime")

# %% [markdown]
# ### 3) Data Split: Train and Evaluation datasets.
#
# - We are tracking data from past 120 timestamps (120 hours = 5 days).
# - This data will be used to predict the temperature after 12 timestamps (12 hours).
# - Since every feature has values with varying ranges, we do normalization to confine feature values to a range of [0, 1] before training a neural network.
# - We do this by subtracting the mean and dividing by the standard deviation of each feature in the *normalize* function
# - The model is shown data for first 5 days i.e. 120 observations, that are sampled every hour.
# - The temperature after 12 hours observation will be used as a label.

# %%
# 70% of the data will be used for training, the rest for testing
split_fraction = 0.7
# The number of samples is the number of rows in the data
number_of_samples = df_resampled.shape[0]
# The size in rows of the split dataset
train_split = int(split_fraction * int(number_of_samples))

# Number of samples in the past used to predict the future
past = 120
# Number of samples in the future to predict (the value in the 72nd hour is our label)
future = 12
# Learning rate parameter for the Adam optimizer
learning_rate = 0.001
# Batch size for the model training
batch_size = 256
# Number of epochs for the model training
epochs = 10

# Another way to normalize the data (all columns in the same range)
def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std

# %% [markdown]
# - Let's select the following parameters as our features:
#    - Pressure, Temperature, Saturation vapor pressure, Vapor pressure deficit, Specific humidity, Airtight, Wind speed
#
# - Set the column FormatedDateTime as the index of our dataframe.
#    - This is important since now, FormatedDateTime is used as our datetime field and not as a Feature field
#
# - Normalize all fields
#
# - Generate two datasets:
#    - train_data: Train dataset with our normalized fields
#    - val_data: Validation dataset

# %%
print(
    "The selected parameters are:",
    ", ".join([titles[i] for i in [0, 1, 5, 7, 8, 10, 11]]),
)

selected_features = [feature_keys[i] for i in [0, 1, 5, 7, 8, 10, 11]]
features = df_resampled[selected_features]
features.index = df_resampled["FormatedDateTime"]
print(features.head())

features = normalize(features.values, train_split)
features = pd.DataFrame(features)
print(features.head())

train_data = features.loc[0 : train_split - 1]
val_data = features.loc[train_split:]
# Out:
# The selected parameters are: Pressure, Temperature, Saturation vapor pressure, Vapor pressure deficit, Specific humidity, Airtight, Wind speed
#                        p (mbar)  T (degC)  VPmax (mbar)  VPdef (mbar)  \
# FormatedDateTime
# 2009-01-01 00:00:00  996.528000 -8.304000      3.260000      0.202000
# 2009-01-01 01:00:00  996.525000 -8.065000      3.323333      0.201667
# 2009-01-01 02:00:00  996.745000 -8.763333      3.145000      0.201667
# 2009-01-01 03:00:00  996.986667 -8.896667      3.111667      0.210000
# 2009-01-01 04:00:00  997.158333 -9.348333      3.001667      0.231667
#
#                      sh (g/kg)  rho (g/m**3)  wv (m/s)
# FormatedDateTime
# 2009-01-01 00:00:00   1.910000   1309.196000  0.520000
# 2009-01-01 01:00:00   1.951667   1307.981667  0.316667
# 2009-01-01 02:00:00   1.836667   1311.816667  0.248333
# 2009-01-01 03:00:00   1.811667   1312.813333  0.176667
# 2009-01-01 04:00:00   1.733333   1315.355000  0.290000
#           0         1         2         3         4         5         6
# 0  0.988366 -1.936957 -1.314750 -0.797292 -1.472751  2.198783 -1.116409
# 1  0.988002 -1.909978 -1.306369 -0.797363 -1.457136  2.169559 -1.256715
# 2  1.014643 -1.988807 -1.329968 -0.797363 -1.500234  2.261854 -1.303867
# 3  1.043907 -2.003858 -1.334379 -0.795594 -1.509604  2.285840 -1.353320
# 4  1.064694 -2.054843 -1.348935 -0.790994 -1.538961  2.347009 -1.275116

# %% [markdown]
# Now, here we need to set our Label Dataset.
#
# - We want to use the last 5 days of data, to predict the next 12 hours
# - This means that our label starts at the 12th hour after the history data.
#    - [.......................... **.** ]
#    - -----Start----->
# - And it will end at the end of our train dataset size.
#    - <-------- Train ---------> <--- Test --->
#    - [.................................................**|**...........]
#    - ----------End---------->

# %%
start = past + future
end = start + train_split

x_train = train_data[[i for i in range(7)]].values
y_train = features.iloc[start:end][[1]]

step = 1
sequence_length = past

# %% [markdown]
# The *timeseries_dataset_from_array* function takes in a sequence of data-points gathered at equal intervals, along with time series parameters such as length of the sequences/windows, spacing between two sequence/windows, etc., to produce batches of sub-timeseries inputs and targets sampled from the main timeseries.
#
# - Input data (hour features) = x_train
# - The **corresponding** value of the temperature 12 hours into the future = y_train
# - Since we want to use 5 days of data to predict the future temperature then: sequence_length = 120
# - Since we want to sample every hour then: sampling_rate = 1
# - Let's use a common batch size of 256 (variable above)

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

# %% [markdown]
# Now let's prepare our validation dataset:
#
# - The validation dataset must not contain the last 120+12 rows as we won't have label data for those records, hence these rows must be subtracted from the end of the data.
# - The validation label dataset must start from 120+12 after train_split, hence we must add past + future to label_start.

# %%
x_end = len(val_data) - past - future

label_start = train_split + past + future

x_val = val_data.iloc[:x_end][[i for i in range(7)]].values
y_val = features.iloc[label_start:][[1]]

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)


for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (256, 120, 7)
# Target shape: (256, 1)

# %% [markdown]
# ### 4) Define and Compile your model:
# - An input layer
# - A Long Short-Term Memory Hidden Layer with 32 units. LSTM is a type of recurrent neural network layer that is well-suited for time series data.
# - An output Dense Layer (Linear Activation function)

# %%
inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
lstm_out = keras.layers.LSTM(32)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 7)]          0
#
#  lstm (LSTM)                 (None, 32)                5120
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 5153 (20.13 KB)
# Trainable params: 5153 (20.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 5) Train your model:
#
# Specify the file path where the model's weights will be saved with:
# `path_checkpoint = "model_checkpoint.weights.h5"`
#
# We want to add a callback to stop training when a monitored metric stops improving:
# `es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)`
#
# Train the model using Fit

# %%
path_checkpoint = "model_checkpoint.weights.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Epoch 1/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.3831
# Epoch 1: val_loss improved from inf to 0.22031, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 11s 89ms/step - loss: 0.3822 - val_loss: 0.2203
# Epoch 2/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1844
# Epoch 2: val_loss improved from 0.22031 to 0.18142, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 8s 83ms/step - loss: 0.1843 - val_loss: 0.1814
# Epoch 3/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1512
# Epoch 3: val_loss improved from 0.18142 to 0.16007, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 8s 84ms/step - loss: 0.1511 - val_loss: 0.1601
# Epoch 4/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1337
# Epoch 4: val_loss improved from 0.16007 to 0.15074, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 8s 86ms/step - loss: 0.1337 - val_loss: 0.1507
# Epoch 5/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1260
# Epoch 5: val_loss improved from 0.15074 to 0.14381, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 9s 96ms/step - loss: 0.1260 - val_loss: 0.1438
# Epoch 6/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1202
# Epoch 6: val_loss improved from 0.14381 to 0.13465, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 8s 86ms/step - loss: 0.1201 - val_loss: 0.1347
# Epoch 7/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1146
# Epoch 7: val_loss improved from 0.13465 to 0.12619, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 9s 89ms/step - loss: 0.1145 - val_loss: 0.1262
# Epoch 8/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1110
# Epoch 8: val_loss improved from 0.12619 to 0.12194, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 8s 88ms/step - loss: 0.1109 - val_loss: 0.1219
# Epoch 9/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1101
# Epoch 9: val_loss improved from 0.12194 to 0.11966, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 9s 93ms/step - loss: 0.1100 - val_loss: 0.1197
# Epoch 10/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1066
# Epoch 10: val_loss improved from 0.11966 to 0.11750, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 9s 93ms/step - loss: 0.1066 - val_loss: 0.1175

# %% [markdown]
# Plot the results of your training:

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %% [markdown]
# Make 5 predictions and display the predicted value

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 5) * 2])
    plt.xlabel("Time-Step")
    plt.show()
    return


for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        12,
        "Single Step Prediction",
    )
# Out:
# 8/8 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 11ms/step
# 8/8 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 13ms/step

# %% [markdown]
# Now make a Time Series Forecasting where using the last 3 days you will predict the weather in the next 3 hours.

# %%
past = 72  # 3 days (72 hours)
future = 3  # Predict the next 3 hours
learning_rate = 0.001
batch_size = 256
epochs = 20 # More epochs

# %%
def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std

selected_features = [feature_keys[i] for i in [0, 1, 5, 7, 8, 10, 11]]
features = df_resampled[selected_features]
features.index = df_resampled["FormatedDateTime"]

features = normalize(features.values, train_split)
features = pd.DataFrame(features)

train_data = features.loc[0:train_split - 1]
val_data = features.loc[train_split:]

start = past + future
end = start + train_split

x_train = train_data[[i for i in range(7)]].values
y_train = features.iloc[start:end][[1]]

step = 1
sequence_length = past

dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

x_end = len(val_data) - past - future
label_start = train_split + past + future

x_val = val_data.iloc[:x_end][[i for i in range(7)]].values
y_val = features.iloc[label_start:][[1]]

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in dataset_train.take(1):
    inputs, targets = batch

inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
lstm_out = keras.layers.LSTM(32)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()

path_checkpoint = "model_checkpoint.weights.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback],
)

def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

visualize_loss(history, "Training and Validation Loss")
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 72, 7)]           0
#
#  lstm_1 (LSTM)               (None, 32)                5120
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5153 (20.13 KB)
# Trainable params: 5153 (20.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.3126
# Epoch 1: val_loss improved from inf to 0.19235, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 8s 59ms/step - loss: 0.3125 - val_loss: 0.1924
# Epoch 2/10
# 96/96 [==============================] - ETA: 0s - loss: 0.1638
# Epoch 2: val_loss improved from 0.19235 to 0.14678, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 5s 52ms/step - loss: 0.1638 - val_loss: 0.1468
# Epoch 3/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.1134
# Epoch 3: val_loss improved from 0.14678 to 0.10536, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 5s 54ms/step - loss: 0.1139 - val_loss: 0.1054
# Epoch 4/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.0854
# Epoch 4: val_loss improved from 0.10536 to 0.09571, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 5s 52ms/step - loss: 0.0859 - val_loss: 0.0957
# Epoch 5/10
# 96/96 [==============================] - ETA: 0s - loss: 0.0761
# Epoch 5: val_loss improved from 0.09571 to 0.08291, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 5s 51ms/step - loss: 0.0761 - val_loss: 0.0829
# Epoch 6/10
# 96/96 [==============================] - ETA: 0s - loss: 0.0691
# Epoch 6: val_loss improved from 0.08291 to 0.07735, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 5s 52ms/step - loss: 0.0691 - val_loss: 0.0773
# Epoch 7/10
# 96/96 [==============================] - ETA: 0s - loss: 0.0642
# Epoch 7: val_loss improved from 0.07735 to 0.07402, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 5s 52ms/step - loss: 0.0642 - val_loss: 0.0740
# Epoch 8/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.0604
# Epoch 8: val_loss improved from 0.07402 to 0.07029, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 5s 52ms/step - loss: 0.0607 - val_loss: 0.0703
# Epoch 9/10
# 95/96 [============================>.] - ETA: 0s - loss: 0.0579
# Epoch 9: val_loss improved from 0.07029 to 0.06641, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 5s 51ms/step - loss: 0.0582 - val_loss: 0.0664
# Epoch 10/10
# 96/96 [==============================] - ETA: 0s - loss: 0.0575
# Epoch 10: val_loss improved from 0.06641 to 0.06363, saving model to model_checkpoint.weights.h5
# 96/96 [==============================] - 5s 52ms/step - loss: 0.0575 - val_loss: 0.0636

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i: 
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], future + 5])
    plt.xlabel("Time-Step")
    plt.show()
    return

for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        3,
        "Single Step Prediction")
# Out:
# 8/8 [==============================] - 1s 11ms/step
# 8/8 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 10ms/step

# %%
def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std

selected_features = [feature_keys[i] for i in [0, 1, 5, 7, 8, 10, 11]]
features = df_resampled[selected_features]
features.index = df_resampled["FormatedDateTime"]

features = normalize(features.values, train_split)
features = pd.DataFrame(features)

train_data = features.loc[0:train_split - 1]
val_data = features.loc[train_split:]

start = past + future
end = start + train_split

x_train = train_data[[i for i in range(7)]].values
y_train = features.iloc[start:end][[1]] 

step = 1
sequence_length = past

dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

x_end = len(val_data) - past - future
label_start = train_split + past + future

x_val = val_data.iloc[:x_end][[i for i in range(7)]].values
y_val = features.iloc[label_start:][[1]]

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))

lstm_out = keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=regularizers.l2(0.001))(inputs)
lstm_out = keras.layers.Dropout(0.3)(lstm_out)
lstm_out = keras.layers.LSTM(32)(lstm_out)

dense_out = keras.layers.Dense(32, activation="relu")(lstm_out)
dense_out = keras.layers.Dense(16, activation="relu")(dense_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=optimizers.Adam(learning_rate=0.0005), loss="huber_loss")
model.summary()

reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)

es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)
path_checkpoint = "model_checkpoint_v2.weights.h5"
modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback, reduce_lr],
)

def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

visualize_loss(history, "Training and Validation Loss with Enhanced Model")
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 72, 7)]           0
#
#  lstm_2 (LSTM)               (None, 72, 64)            18432
#
#  dropout (Dropout)           (None, 72, 64)            0
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 32449 (126.75 KB)
# Trainable params: 32449 (126.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 96/96 [==============================] - ETA: 0s - loss: 0.2270
# Epoch 1: val_loss improved from inf to 0.13304, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 20s 164ms/step - loss: 0.2270 - val_loss: 0.1330 - lr: 5.0000e-04
# Epoch 2/20
# 96/96 [==============================] - ETA: 0s - loss: 0.1237
# Epoch 2: val_loss improved from 0.13304 to 0.11641, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 160ms/step - loss: 0.1237 - val_loss: 0.1164 - lr: 5.0000e-04
# Epoch 3/20
# 96/96 [==============================] - ETA: 0s - loss: 0.1051
# Epoch 3: val_loss improved from 0.11641 to 0.09974, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 162ms/step - loss: 0.1051 - val_loss: 0.0997 - lr: 5.0000e-04
# Epoch 4/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0804
# Epoch 4: val_loss improved from 0.09974 to 0.07527, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 159ms/step - loss: 0.0804 - val_loss: 0.0753 - lr: 5.0000e-04
# Epoch 5/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0625
# Epoch 5: val_loss did not improve from 0.07527
# 96/96 [==============================] - 15s 160ms/step - loss: 0.0625 - val_loss: 0.0789 - lr: 5.0000e-04
# Epoch 6/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0603
# Epoch 6: val_loss improved from 0.07527 to 0.06064, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 157ms/step - loss: 0.0603 - val_loss: 0.0606 - lr: 5.0000e-04
# Epoch 7/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0509
# Epoch 7: val_loss improved from 0.06064 to 0.05062, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 157ms/step - loss: 0.0509 - val_loss: 0.0506 - lr: 5.0000e-04
# Epoch 8/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0469
# Epoch 8: val_loss improved from 0.05062 to 0.05038, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 157ms/step - loss: 0.0469 - val_loss: 0.0504 - lr: 5.0000e-04
# Epoch 9/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0471
# Epoch 9: val_loss did not improve from 0.05038
# 96/96 [==============================] - 15s 155ms/step - loss: 0.0471 - val_loss: 0.0534 - lr: 5.0000e-04
# Epoch 10/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0464
# Epoch 10: val_loss did not improve from 0.05038
# 96/96 [==============================] - 16s 169ms/step - loss: 0.0464 - val_loss: 0.0509 - lr: 5.0000e-04
# Epoch 11/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 11: val_loss improved from 0.05038 to 0.04194, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 155ms/step - loss: 0.0428 - val_loss: 0.0419 - lr: 5.0000e-04
# Epoch 12/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0411
# Epoch 12: val_loss did not improve from 0.04194
# 96/96 [==============================] - 15s 161ms/step - loss: 0.0411 - val_loss: 0.0423 - lr: 5.0000e-04
# Epoch 13/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0387
# Epoch 13: val_loss improved from 0.04194 to 0.04055, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 155ms/step - loss: 0.0387 - val_loss: 0.0406 - lr: 5.0000e-04
# Epoch 14/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0365
# Epoch 14: val_loss improved from 0.04055 to 0.03847, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 16s 163ms/step - loss: 0.0365 - val_loss: 0.0385 - lr: 5.0000e-04
# Epoch 15/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0358
# Epoch 15: val_loss improved from 0.03847 to 0.03669, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 155ms/step - loss: 0.0358 - val_loss: 0.0367 - lr: 5.0000e-04
# Epoch 16/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0347
# Epoch 16: val_loss did not improve from 0.03669
# 96/96 [==============================] - 15s 156ms/step - loss: 0.0347 - val_loss: 0.0370 - lr: 5.0000e-04
# Epoch 17/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0358
# Epoch 17: val_loss did not improve from 0.03669
# 96/96 [==============================] - 15s 152ms/step - loss: 0.0358 - val_loss: 0.0442 - lr: 5.0000e-04
# Epoch 18/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0415
# Epoch 18: val_loss did not improve from 0.03669
# 96/96 [==============================] - 15s 156ms/step - loss: 0.0415 - val_loss: 0.0549 - lr: 5.0000e-04
# Epoch 19/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0397
# Epoch 19: val_loss improved from 0.03669 to 0.03621, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 15s 158ms/step - loss: 0.0397 - val_loss: 0.0362 - lr: 2.5000e-04
# Epoch 20/20
# 96/96 [==============================] - ETA: 0s - loss: 0.0330
# Epoch 20: val_loss improved from 0.03621 to 0.03145, saving model to model_checkpoint_v2.weights.h5
# 96/96 [==============================] - 16s 163ms/step - loss: 0.0330 - val_loss: 0.0315 - lr: 2.5000e-04

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:  # Para el historial
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], future + 5])
    plt.xlabel("Time-Step")
    plt.show()
    return

for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        3,
        "Single Step Prediction")
# Out:
# 8/8 [==============================] - 1s 25ms/step
# 8/8 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
